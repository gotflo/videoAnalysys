# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="gkBuj8Wdp3N0HuKe2KcP")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(12)
dataset = version.download("yolov8")
# Out:
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: pip install --upgrade pip
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# xtracting Dataset Version Zip to football-players-detection-12 in yolov8:: 100%

# %%
from ultralytics import YOLO

# Chargement d'un modèle YOLOx8 pré-entraîné 
model = YOLO("yolov8x.pt")
# Out:
# ...
# 00%|████████████████████████████████████████| 131M/131M [00:05<00:00, 23.5MB/s]

# %%
# Entraîner le modèle avec vos données annotées
model.train(
    data="/Users/mouhamedndiaye/Desktop/JupyterProject/football-players-detection-12/data.yaml",
    epochs=5,
    imgsz=640,
    batch=12,
    name="yolo_football_detector"
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.49 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics 8.3.48 🚀 Python-3.12.5 torch-2.2.2 CPU (Intel Core(TM) i5-8257U 1.40GHz)
# ...

# %%
# Charger le modèle entraîné
trained_model = "runs/detect/yolo_football_detector/weights/best.pt"
model = YOLO(trained_model)

# Appliquer la détection sur une vidéo
input_video = "video1.mp4"
output_video = "football_match_detected.mp4"

results = model.predict(source=input_video, save=True, conf=0.5)
print(f"Vidéo avec détection sauvegardée dans {output_video}")
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /Users/mouhamedndiaye/Desktop/JupyterProject/video1.mp4: 384x640 21 players, 1 referee, 1089.4ms
# video 1/1 (frame 2/750) /Users/mouhamedndiaye/Desktop/JupyterProject/video1.mp4: 384x640 21 players, 2 referees, 806.2ms
# video 1/1 (frame 3/750) /Users/mouhamedndiaye/Desktop/JupyterProject/video1.mp4: 384x640 20 players, 2 referees, 832.6ms
# ...

# %%
from IPython.display import Video

# Afficher la vidéo de sortie
Video("football_match_detected.mp4", embed=True)
# Out:
# <video controls  >
#  <source src="..._match_detected.mp4" type="None">
#  Your browser does not support the video tag.
#  </video>
